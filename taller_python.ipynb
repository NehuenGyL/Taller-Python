# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# <img src="img/simpleza_python.png" style="width:75%; height:100%;">

# %% [markdown]
# ### Vamos a complicar un poco más las cosas. Creemos una variable que almacene un número

# %% [markdown]
# <img src="img/variable.jpg" style="width:25%; height:40%;">

# %%
x = 5

# %% [markdown]
# #### A diferencia de otros lenguajes de programación, no es necesario decirle a Python el tipo de dato que queremos almacenar en x. En otro lenguajes es necesario especificar que x almacenará un valor entero, pero no es el caso. Python es muy listo y al ver el número 5, sabrá de que tipo tiene que ser la x.
# #### Vamos a usar print a ver que sucede

# %%
print(x)
# Out:
# 5

# %% [markdown]
# #### Vamos a sumar dos variables e imprimir su valor. Lo primero vamos a declararlas, con nombres a y b. Declarar una variable significa “crearla”.

# %%
# Declaramos las variables a, b
# y asignamos dos valores
a = 3
b = 7

# %% [markdown]
# #### Ahora vamos a sumar a + b

# %%
a + b

# %% [markdown]
# #### También se pueden sumar variables tipo string

# %%
var1 = 'Buenos '
var2 = 'Aires'

# %%
var1 + var2
# Out:
# 'Buenos Aires'

# %% [markdown]
# #### Es importante que sólo usemos variables que hayan sido definidas, porque de lo contrario tendremos un error. Si hacemos:

# %%
print(z)

# %% [markdown]
# #### Vamos a ver los tipos de variables que existen

# %%
type(10)
# Out:
# int

# %%
type(1.0)
# Out:
# float

# %%
type('10')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(1j)
# Out:
# complex

# %% [markdown]
# ### Ahora vamos a ir al siguiente nivel, estan listos?

# %% [markdown]
# #### Vamos con los ejemplos condicionales
# Podemos empezar a complicar un poco más las cosas con el uso de una sentencia condicional. Te lo explicamos más adelante en este post sobre el if.
#
# ##### El siguiente código hace uso del if para comprobar si la a es igual == a 10. Si lo es, se imprimirá “Es 10” y si no lo es “No es 10”.

# %%
a = 10
if a == 10:
    print("Es 10")
else:
    print("No es 10")

# %% [markdown]
# #### Vamos a crear dos variables y un condicional que informe si son del mismo tipo de dato para ver otro ejemplo

# %%
a = 2
b = 'hola'
if (type(a) == type(b)):
    print('Las variables son del mismo tipo de dato')
else:
    print('Las variables son de tipos de dato diferentes')

# %% [markdown]
# ### Ahora vamos a ver Bucles: while, for, break, continue
# El while y for permiten crear bucles que ejecutan una sección de código repetidas veces. Por otro lado el continue y el break permiten realizar alteraciones sobre el bucle.

# %% [markdown]
# #### El ciclo while ejecuta su sección de código mientras se cumpla una determinada condición.

# %%
x = 0
while x < 8:
    print(x)
    x += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# #### El ciclo for permite iterar clases iterables, ejecutando la sección de código tantas veces como elementos tiene el iterable.

# %%
for i in range(8):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# #### El continue salta hasta el final del bloque, dejando sin ejecutar lo restante, pero continúa en la siguiente iteración. (del ciclo for)

# %%
for i in range(8):
    if i == 3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5
# 6
# 7

# %% [markdown]
# #### Por último, el break rompe la ejecución del bucle, saliendo del mismo. (ciclo while)

# %%
x = 0
while True:
    print(x)
    if x == 10:
        break
    x += 2

# %% [markdown]
# #### Ahora vamos a ver la magia de la automatizacion

# %% [markdown]
# ##### Este ciclo while imprime números del 0 al 19 y luego reinicia x a 0 automáticamente. Esto se logra usando la expresión x = (x + 1) % 20, que incrementa x en 1 en cada iteración y luego utiliza el operador módulo % para reiniciarlo a 0 cuando alcanza 20. El bucle while se ejecuta indefinidamente, ya que x nunca supera 19

# %%
x = 0
while x < 20:
    print(x)
    x = (x+1) % 20

# %% [markdown]
# #### Ahora vamos a crear nuestra primera funcion, y luego le vamos a agregar texto de 2 maneras

# %%
def funcion_suma(a, b):
    return a + b

funcion_suma(2, 2)
# Out:
# 4

# %%
def funcion_suma(a, b):
    print("La suma es", a + b)

funcion_suma(5, 5)
# Out:
# La suma es 10

# %%
def funcion_suma(a, b):
    return a + b

suma = funcion_suma(3, 5)
print("La suma es", suma)
# Out:
# La suma es 8

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5f98bef6-0a6a-4428-9e70-ade564b7e96d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
