# %% [markdown]
# #### Vamos a ver los tipos de variables que existen

# %%
type(10)
# Out:
# int

# %%
type(1.0)
# Out:
# float

# %%
type('10')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(1j)
# Out:
# complex

# %% [markdown]
# #### Tipos de variables validas e invalidas

# %%
# Válido
_variable = 10
vari_able = 20
variable10 = 30
variable = 60
variaBle = 10

# No válido
2variable = 10
var-iable = 10
var iable = 10
